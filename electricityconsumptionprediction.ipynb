# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DATA READING

# %%
ec=pd.read_csv(r"C:\Users\jyoti\Downloads\archive (1)\powerconsumption.csv")
ec
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# ...

# %%
ec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datetime                52416 non-null  object
#  1   Temperature             52416 non-null  float64
#  2   Humidity                52416 non-null  float64
#  3   WindSpeed               52416 non-null  float64
#  4   GeneralDiffuseFlows     52416 non-null  float64
#  5   DiffuseFlows            52416 non-null  float64
#  6   PowerConsumption_Zone1  52416 non-null  float64
#  7   PowerConsumption_Zone2  52416 non-null  float64
#  8   PowerConsumption_Zone3  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
ec.head()
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
# 3  1/1/2017 0:30        6.121      75.0      0.083                0.091
# 4  1/1/2017 0:40        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3
# 0             20240.96386
# 1             20131.08434
# 2             19668.43373
# 3             18899.27711
# ...

# %%
ec.tail()
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 52411                0.040         0.096             31160.45627
# 52412                0.051         0.093             30430.41825
# 52413                0.084         0.074             29590.87452
# 52414                0.066         0.089             28958.17490
# 52415                0.062         0.111             28349.80989
#
#        PowerConsumption_Zone2  PowerConsumption_Zone3
# 52411             26857.31820             14780.31212
# 52412             26124.57809             14428.81152
# 52413             25277.69254             13806.48259
# ...

# %%
ec.isnull().sum()
# Out:
# Datetime                  0
# Temperature               0
# Humidity                  0
# WindSpeed                 0
# GeneralDiffuseFlows       0
# DiffuseFlows              0
# PowerConsumption_Zone1    0
# PowerConsumption_Zone2    0
# PowerConsumption_Zone3    0
# dtype: int64

# %%
for i in ec:
    print(i,"=",ec[i].unique())
# Out:
# Datetime = ['1/1/2017 0:00' '1/1/2017 0:10' '1/1/2017 0:20' ... '12/30/2017 23:30'
#  '12/30/2017 23:40' '12/30/2017 23:50']
# Temperature = [6.559 6.414 6.313 ... 6.947 6.758 6.58 ]
# Humidity = [73.8  74.5  75.   ... 41.96 41.22 45.89]
# WindSpeed = [0.083 0.08  0.081 0.085 0.082 0.084 0.079 0.076 2.66  4.93  4.924 4.923
#  4.918 4.916 2.451 0.077 0.074 0.075 0.073 0.086 0.078 0.072 0.071 0.091
#  0.087 0.09  0.088 0.089 0.094 0.069 0.092 2.287 4.708 1.97  0.14  0.093
#  0.097 0.095 0.106 0.098 0.1   0.099 0.096 0.068 0.07  0.067 0.066 0.065
#  0.295 2.981 4.917 4.914 4.915 0.907 4.913 4.921 4.353 0.464 4.919 4.92
#  1.437 1.324 0.245 0.805 4.912 3.725 1.682 4.922 4.911 4.926 4.925 4.91
#  4.909 4.908 4.928 0.653 1.026 4.927 4.907 3.982 0.111 1.236 4.65  2.764
#  4.906 4.905 4.904 4.929 4.797 0.102 0.108 0.932 3.627 1.966 2.54  0.118
#  0.117 0.119 0.107 0.116 0.127 0.105 0.062 1.055 4.405 0.139 0.561 0.555
#  0.865 0.449 0.271 0.421 0.263 0.437 0.642 0.18  0.258 0.101 0.064 2.654
# ...

# %%
for i in ec:
    print(i,sum(ec[i]=="?"))
# Out:
# Datetime 0
# Temperature 0
# Humidity 0
# WindSpeed 0
# GeneralDiffuseFlows 0
# DiffuseFlows 0
# PowerConsumption_Zone1 0
# PowerConsumption_Zone2 0
# PowerConsumption_Zone3 0

# %%
ec.describe(include='all')
# Out:
#              Datetime   Temperature      Humidity     WindSpeed  \
# count           52416  52416.000000  52416.000000  52416.000000
# unique          52416           NaN           NaN           NaN
# top     1/1/2017 0:00           NaN           NaN           NaN
# freq                1           NaN           NaN           NaN
# mean              NaN     18.810024     68.259518      1.959489
# std               NaN      5.815476     15.551177      2.348862
# min               NaN      3.247000     11.340000      0.050000
# 25%               NaN     14.410000     58.310000      0.078000
# 50%               NaN     18.780000     69.860000      0.086000
# 75%               NaN     22.890000     81.400000      4.915000
# max               NaN     40.010000     94.800000      6.483000
#
#         GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# count          52416.000000  52416.000000            52416.000000
# ...

# %%
ec=ec.drop(['PowerConsumption_Zone2','PowerConsumption_Zone3'],axis=1)

# %%
ec=ec.rename(columns={ 'PowerConsumption_Zone1': 'TotalPowerConsumption'})
ec
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  TotalPowerConsumption
# 0                    0.051         0.119            34055.69620
# 1                    0.070         0.085            29814.68354
# 2                    0.062         0.100            29128.10127
# ...

# %% [markdown]
# # FEATURE ENGINEERING

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['minute'] = df.index.minute
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['day'] = df.index.month
    df['year'] = df.index.year
    df['season'] = df['month'] % 12 // 3 + 1
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week

    # Additional features
    df['is_weekend'] = df['dayofweek'].isin([5, 6]).astype(int)
    df['is_month_start'] = (df['dayofmonth'] == 1).astype(int)
    df['is_month_end'] = (df['dayofmonth'] == df.index.days_in_month).astype(int)
    df['is_quarter_start'] = (df['dayofmonth'] == 1) & (df['month'] % 3 == 1).astype(int)
    df['is_quarter_end'] = (df['dayofmonth'] == df.groupby(['year', 'quarter'])['dayofmonth'].transform('max'))

    # Additional features
    df['is_working_day'] = df['dayofweek'].isin([0, 1, 2, 3, 4]).astype(int)
    df['is_business_hours'] = df['hour'].between(9, 17).astype(int)
    df['is_peak_hour'] = df['hour'].isin([8, 12, 18]).astype(int)

    # Minute-level features
    df['minute_of_day'] = df['hour'] * 60 + df['minute']
    df['minute_of_week'] = (df['dayofweek'] * 24 * 60) + df['minute_of_day']

    return df.astype(float)

# %%
ec['Datetime']=pd.to_datetime(ec.Datetime)
ec.sort_values(by='Datetime', ascending=True, inplace=True)

chronological_order = ec['Datetime'].is_monotonic_increasing

# %%
chronological_order
# Out:
# True

# %%
df = ec.set_index('Datetime')
df = create_features(df)

# %%
df[[ 'year', 'month', 'day','minute', 'dayofyear', 'weekofyear', 'quarter', 'season']].head()
# Out:
#                        year  month  day  minute  dayofyear  weekofyear  \
# Datetime
# 2017-01-01 00:00:00  2017.0    1.0  1.0     0.0        1.0        52.0
# 2017-01-01 00:10:00  2017.0    1.0  1.0    10.0        1.0        52.0
# 2017-01-01 00:20:00  2017.0    1.0  1.0    20.0        1.0        52.0
# 2017-01-01 00:30:00  2017.0    1.0  1.0    30.0        1.0        52.0
# 2017-01-01 00:40:00  2017.0    1.0  1.0    40.0        1.0        52.0
#
#                      quarter  season
# Datetime
# 2017-01-01 00:00:00      1.0     1.0
# 2017-01-01 00:10:00      1.0     1.0
# 2017-01-01 00:20:00      1.0     1.0
# 2017-01-01 00:30:00      1.0     1.0
# 2017-01-01 00:40:00      1.0     1.0

# %%
plt.plot(ec.Temperature[0:10],ec.Humidity[0:10])
plt.show()

# %%
plt.scatter(ec.Temperature,ec.Humidity,s=ec['Humidity']*10,c='Blue',alpha=0.5,edgecolors='w')
plt.show()

# %% [markdown]
# # DATA VISUALIZATION

# %%
sns.pairplot(ec)

# %%
ec1=ec.drop(['Datetime'],axis=1)
ec1
# Out:
#        Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  DiffuseFlows  \
# 0            6.559      73.8      0.083                0.051         0.119
# 1            6.414      74.5      0.083                0.070         0.085
# 2            6.313      74.5      0.080                0.062         0.100
# 3            6.121      75.0      0.083                0.091         0.096
# 4            5.921      75.7      0.081                0.048         0.085
# ...            ...       ...        ...                  ...           ...
# 52411        7.010      72.4      0.080                0.040         0.096
# 52412        6.947      72.6      0.082                0.051         0.093
# 52413        6.900      72.8      0.086                0.084         0.074
# 52414        6.758      73.0      0.080                0.066         0.089
# 52415        6.580      74.1      0.081                0.062         0.111
#
#        TotalPowerConsumption
# 0                34055.69620
# ...

# %%
cor=ec1.corr()
cor
# Out:
#                        Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# Temperature               1.000000 -0.460243   0.477109             0.460294
# Humidity                 -0.460243  1.000000  -0.135853            -0.468138
# WindSpeed                 0.477109 -0.135853   1.000000             0.133733
# GeneralDiffuseFlows       0.460294 -0.468138   0.133733             1.000000
# DiffuseFlows              0.196522 -0.256886  -0.000972             0.564718
# TotalPowerConsumption     0.440221 -0.287421   0.167444             0.187965
#
#                        DiffuseFlows  TotalPowerConsumption
# Temperature                0.196522               0.440221
# Humidity                  -0.256886              -0.287421
# WindSpeed                 -0.000972               0.167444
# GeneralDiffuseFlows        0.564718               0.187965
# DiffuseFlows               1.000000               0.080274
# TotalPowerConsumption      0.080274               1.000000

# %%
correlation_matrix = df[['Temperature', 'Humidity', 'WindSpeed', 'TotalPowerConsumption']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 52416 entries, 2017-01-01 00:00:00 to 2017-12-30 23:50:00
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Temperature            52416 non-null  float64
#  1   Humidity               52416 non-null  float64
#  2   WindSpeed              52416 non-null  float64
#  3   GeneralDiffuseFlows    52416 non-null  float64
#  4   DiffuseFlows           52416 non-null  float64
#  5   TotalPowerConsumption  52416 non-null  float64
#  6   hour                   52416 non-null  float64
#  7   minute                 52416 non-null  float64
#  8   dayofweek              52416 non-null  float64
#  9   quarter                52416 non-null  float64
#  10  month                  52416 non-null  float64
#  11  day                    52416 non-null  float64
#  12  year                   52416 non-null  float64
# ...

# %%
swp_list=['Temperature','Humidity','WindSpeed','DiffuseFlows','GeneralDiffuseFlows','hour','minute','dayofweek','quarter','month','day','year','season','dayofyear','dayofmonth','weekofyear','is_weekend','is_month_start','is_month_end','is_quarter_start','is_quarter_end','is_working_day','is_business_hours','is_peak_hour','minute_of_day','minute_of_week','TotalPowerConsumption']

# %%
df = df.reindex(columns=swp_list)

# %%
df.head()
# Out:
#                      Temperature  Humidity  WindSpeed  DiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00        6.559      73.8      0.083         0.119
# 2017-01-01 00:10:00        6.414      74.5      0.083         0.085
# 2017-01-01 00:20:00        6.313      74.5      0.080         0.100
# 2017-01-01 00:30:00        6.121      75.0      0.083         0.096
# 2017-01-01 00:40:00        5.921      75.7      0.081         0.085
#
#                      GeneralDiffuseFlows  hour  minute  dayofweek  quarter  \
# Datetime
# 2017-01-01 00:00:00                0.051   0.0     0.0        6.0      1.0
# 2017-01-01 00:10:00                0.070   0.0    10.0        6.0      1.0
# 2017-01-01 00:20:00                0.062   0.0    20.0        6.0      1.0
# 2017-01-01 00:30:00                0.091   0.0    30.0        6.0      1.0
# 2017-01-01 00:40:00                0.048   0.0    40.0        6.0      1.0
#
#                      month  ...  is_month_start  is_month_end  \
# ...

# %%
# Focus on specific correlations
temp_power_corr = cor['Temperature']['TotalPowerConsumption']
print(f"Correlation between temperature and Zone 1 power consumption: {temp_power_corr:.2f}")
# Out:
# Correlation between temperature and Zone 1 power consumption: 0.44

# %%
plt.figure(figsize=(8, 6))
plt.scatter(ec['Temperature'], ec['TotalPowerConsumption'], alpha=0.5,c='violet',edgecolors='w')
plt.title('Temperature vs TotalPowerConsumption')
plt.xlabel('Temperature')
plt.ylabel('TotalPowerConsumption')
plt.show()

# %%
#input and output
ip = df.iloc[:, :-1]
op = df.iloc[:, -1]

# %%
ip,op
# Out:
# (                     Temperature  Humidity  WindSpeed  DiffuseFlows  \
#  Datetime
#  2017-01-01 00:00:00        6.559      73.8      0.083         0.119
#  2017-01-01 00:10:00        6.414      74.5      0.083         0.085
#  2017-01-01 00:20:00        6.313      74.5      0.080         0.100
#  2017-01-01 00:30:00        6.121      75.0      0.083         0.096
#  2017-01-01 00:40:00        5.921      75.7      0.081         0.085
#  ...                          ...       ...        ...           ...
#  2017-12-30 23:10:00        7.010      72.4      0.080         0.096
#  2017-12-30 23:20:00        6.947      72.6      0.082         0.093
#  2017-12-30 23:30:00        6.900      72.8      0.086         0.074
#  2017-12-30 23:40:00        6.758      73.0      0.080         0.089
#  2017-12-30 23:50:00        6.580      74.1      0.081         0.111
#
#                       GeneralDiffuseFlows  hour  minute  dayofweek  quarter  \
#  Datetime
# ...

# %% [markdown]
# # MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(ip,op,test_size=0.2,random_state=1)

# %%
xtrain
# Out:
#                      Temperature  Humidity  WindSpeed  DiffuseFlows  \
# Datetime
# 2017-11-07 15:20:00        21.60     63.44      0.076       422.300
# 2017-11-04 16:30:00        23.11     55.84      0.073       192.900
# 2017-02-18 01:10:00         9.92     87.70      0.070         0.189
# 2017-12-14 14:40:00        14.06     69.08      0.083       117.900
# 2017-03-13 16:00:00        18.02     61.35      0.074       111.000
# ...                          ...       ...        ...           ...
# 2017-12-14 14:50:00        14.11     69.92      0.084       134.600
# 2017-08-14 18:30:00        25.99     38.95      4.911       255.300
# 2017-02-06 01:20:00        10.08     49.68      0.085         0.074
# 2017-03-26 12:40:00        19.04     54.21      0.085        43.110
# 2017-08-18 04:30:00        21.12     74.50      0.070         0.089
#
#                      GeneralDiffuseFlows  hour  minute  dayofweek  quarter  \
# Datetime
# ...

# %%
#Standardization
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
xtrain1=sc.fit_transform(xtrain)
xtest1=sc.fit_transform(xtest)

# %%
xtrain1
# Out:
# array([[ 0.47579645, -0.30773366, -0.80393478, ..., -0.37740799,
#          0.48980805, -0.92222025],
#        [ 0.73533262, -0.79575577, -0.80521146, ..., -0.37740799,
#          0.65793542,  1.07963062],
#        [-1.5317416 ,  1.2500843 , -0.80648815, ..., -0.37740799,
#         -1.55173854,  0.76372962],
#        ...,
#        [-1.50424107, -1.19131054, -0.80010474, ..., -0.37740799,
#         -1.52772034, -1.70510532],
#        [ 0.03578811, -0.90042367, -0.80010474, ...,  2.64965243,
#          0.10551693,  1.4951091 ],
#        [ 0.39329489,  0.40246695, -0.80648815, ..., -0.37740799,
#         -1.07137463,  0.33795002]])

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
#Model Selection
#linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#Model Training
lr.fit(xtrain1,ytrain)
# Out:
# LinearRegression()

# %%
#Model Testing
lr_pred=lr.predict(xtest1)
lr_pred
# Out:
# array([-2.73385126e+13, -4.97155207e+13, -1.19007337e+13, ...,
#        -2.90556833e+13, -1.01514965e+13,  4.92233998e+13])

# %%
lr_mse = mean_squared_error(lr_pred,ytest)
lr_mse
# Out:
# 1.313213428213907e+27

# %%
lr_accuracy = r2_score(ytest, lr_pred)
lr_accuracy
# Out:
# -2.566911120898146e+19

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor(n_neighbors=5)

# %%
knr.fit(xtrain1,ytrain)
# Out:
# KNeighborsRegressor()

# %%
knr_pred=knr.predict(xtest1)
knr_pred
# Out:
# array([36192.210064, 26300.377358, 44752.5298  , ..., 23105.722282,
#        33018.62648 , 34791.929204])

# %%
knr_mse = mean_squared_error(knr_pred,ytest)
knr_mse
# Out:
# 3089917.031527283

# %%
knr_accuracy = r2_score(ytest, knr_pred)
knr_accuracy
# Out:
# 0.9396020310143522

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf')

# %%
svr.fit(xtrain1,ytrain)
# Out:
# SVR()

# %%
svr_pred=svr.predict(xtest1)
svr_pred
# Out:
# array([32219.01959609, 30844.16684526, 33100.161067  , ...,
#        30194.22877847, 31914.01003762, 33689.31846151])

# %%
svr_mse = mean_squared_error(svr_pred,ytest)
svr_mse
# Out:
# 39211955.531093374

# %%
svr_accuracy = r2_score(ytest, svr_pred)
svr_accuracy
# Out:
# 0.233532017245472

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()

# %%
dtr.fit(xtrain1,ytrain)
# Out:
# DecisionTreeRegressor()

# %%
dtr_pred=dtr.predict(xtest1)
dtr_pred
# Out:
# array([34484.37637, 25207.19201, 44897.48344, ..., 22928.39612,
#        33078.14855, 34139.46903])

# %%
dtr_mse = mean_squared_error(dtr_pred,ytest)
dtr_mse
# Out:
# 1733552.510348273

# %%
dtr_accuracy = r2_score(ytest, dtr_pred)
dtr_accuracy
# Out:
# 0.9661146077105979

# %%
import xgboost as xg
xgbr = xg.XGBRegressor(objective ='reg:linear', n_estimators = 10, seed = 123)

# %%
xgbr.fit(xtrain1,ytrain)
# Out:
# C:\Users\jyoti\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [00:34:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:227: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
# ...

# %%
xgbr_pred=xgbr.predict(xtest1)
xgbr_pred
# Out:
# array([30874.38 , 25854.688, 38298.152, ..., 24109.346, 33832.2  ,
#        35300.203], dtype=float32)

# %%
xgbr_mse = mean_squared_error(xgbr_pred,ytest)
xgbr_mse
# Out:
# 2509037.9975209227

# %%
xgbr_accuracy = r2_score(ytest, xgbr_pred)
xgbr_accuracy
# Out:
# 0.9509563533221548

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators=100)

# %%
rfr.fit(xtrain1,ytrain)
# Out:
# RandomForestRegressor()

# %%
rfr_pred=rfr.predict(xtest1)
rfr_pred
# Out:
# array([32714.2185348, 25478.3126282, 39272.3150762, ..., 21766.2378004,
#        33170.158766 , 34175.3163486])

# %%
rfr_mse = mean_squared_error(rfr_pred,ytest)
rfr_mse
# Out:
# 902483.797439285

# %%
rfr_accuracy = r2_score(ytest, rfr_pred)
rfr_accuracy
# Out:
# 0.982359335913675

# %%
metrics = pd.DataFrame({
    'Algorithm': ['Linear Regression', 'KNN', 'SVM', 'Decision Tree', 'XG Boost','Random Forest'],
    'MSE': [lr_mse,knr_mse,svr_mse,dtr_mse,xgbr_mse,rfr_mse],
    'R2 Score (Accuracy)': [lr_accuracy,knr_accuracy,svr_accuracy,dtr_accuracy,xgbr_accuracy,rfr_accuracy]
})
print(metrics)
# Out:
#            Algorithm           MSE  R2 Score (Accuracy)
# 0  Linear Regression  1.313213e+27        -2.566911e+19
# 1                KNN  3.089917e+06         9.396020e-01
# 2                SVM  3.921196e+07         2.335320e-01
# 3      Decision Tree  1.733553e+06         9.661146e-01
# 4           XG Boost  2.509038e+06         9.509564e-01
# 5      Random Forest  9.024838e+05         9.823593e-01

# %%
# Visualizing the metrics
metrics.set_index('Algorithm', inplace=True)

# Plot MSE
metrics[['MSE']].plot(kind='bar', title="Mean Squared Error by Algorithm", legend=True, color=['red'], rot=45)

# Plot R2 Score
metrics[['R2 Score (Accuracy)']].plot(kind='bar', title="R2 Score (Accuracy) by Algorithm", legend=True, color=['blue'], rot=45)

plt.show()

# %%
new_data = pd.DataFrame({
    'Temperature':[20],
    'Humidity':[60],
    'WindSpeed':[0.8],
    'DiffuseFlows':[0.1],
    'GeneralDiffuseFlows':[0.06],
    'hour':[12],
    'minute':[10],
    'dayofweek':[6],
    'quarter':[2],
    'month':[10],
    'day':[6],
    'year':[6],
    'season':[2],
    'dayofyear':[1],
    'dayofmonth':[6],
    'weekofyear':[6],
    'is_weekend':[0],
    'is_month_start':[1],
    'is_month_end':[0],
    'is_quarter_start':[1],
    'is_quarter_end':[1],
    'is_working_day':[0],
    'is_business_hours':[1],
    'is_peak_hour':[0],
    'minute_of_day':[1200],
    'minute_of_week':[8600]
})

# %% [markdown]
# # PREDICTION RESULT

# %%
new_prediction = rfr.predict(new_data)
print("Predicted Power Consumption:", new_prediction[0])
# Out:
# Predicted Power Consumption: 32065.306671100006
# C:\Users\jyoti\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   warnings.warn(

# %%
import pickle
pickle.dump(rfr,open('model.pkl','wb'))
pickle.dump(sc,open('standardscaler.pkl','wb'))
